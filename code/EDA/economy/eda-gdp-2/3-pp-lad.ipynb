# %%
import datapath
import pandas as pd

# %%
# read lad data
lad = pd.read_csv(r'datasets\Local_Authority_District_(April_2023)_to_LAU1_to_ITL3_to_ITL2_to_ITL1_(January_2021)Lookup.csv')
lad
# Out:
#        LAD23CD               LAD23NM   LAU121CD              LAU121NM  \
# 0    E06000001            Hartlepool  E06000001            Hartlepool
# 1    E06000004      Stockton-on-Tees  E06000004      Stockton-on-Tees
# 2    E06000002         Middlesbrough  E06000002         Middlesbrough
# 3    E06000003  Redcar and Cleveland  E06000003  Redcar and Cleveland
# 4    E06000005            Darlington  E06000005            Darlington
# ..         ...                   ...        ...                   ...
# 383  E07000138               Lincoln  E07000138               Lincoln
# 384  E07000139        North Kesteven  E07000139        North Kesteven
# 385  E07000140         South Holland  E07000140         South Holland
# 386  E07000141        South Kesteven  E07000141        South Kesteven
# 387  E07000142          West Lindsey  E07000142          West Lindsey
#
#     ITL321CD                         ITL321NM ITL221CD  \
# 0      TLC11  Hartlepool and Stockton-on-Tees     TLC1
# ...
